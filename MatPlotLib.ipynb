# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x=[1,2,3,4,5]
y=[5,4,3,2,1]
plt.plot(x,y)
plt.title('Correlation')
plt.show()

# %%
x=[1,2,3,4,5]
y=[5,4,3,2,1]
plt.plot(x,y,'o')
plt.title('Correlation')
plt.show()

# %%
x=[1,2,3,4,5]
y=[5,4,3,2,1]
plt.scatter(x,y)
plt.title('Correlation')
plt.show()

# %%
a=[1,2,2,2,3]
b=[3,3,2,1,1]
plt.scatter(a,b)
plt.scatter(x,y)
plt.title('Correlation2')
plt.show()

# %%
x=['Mon','Tues','Wed','Thurs','Fri']
y=[5,4,3,2,1]
plt.bar(x,y)
plt.title('Sales per day')
plt.show()

# %%
df=pd.DataFrame({'Sales':[4,7,2]},
                index=['sarah','John','Peter'])
plot=df.plot.pie(y='Sales')
plt.title("Sales by Rep")
plt.show()

# %%
# alternate to above
c=['Sarah','John','Peter']
d=[4,2,7]
plt.pie(d,labels=c)
plt.show()
